# %%
#Objective-
# Imporve Customer Exp by analyzing sales data
#Increase revenue

# %%
# !pip install chart_studio
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\ut243\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px

# %%
df=pd.read_csv('Diwali Sales Data.csv')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra�Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# Status              float64
# unnamed1            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape
# Out:
# (11251, 13)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11239, 13)

# %%
#change datatype

# %%
df['Amount']=df['Amount'].astype('int64')

# %%
df.dtypes
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender              object
# Age Group           object
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                object
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#change name of columns

# %%
df.rename(columns={'Marital_Status':'Shaadi_status'},inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Shaadi_status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Shaadi_status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax=sns.countplot(x="Gender",data=df)

# %%
sales_gen=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

# %%
sales_gen
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sns.barplot(x='Gender',y='Amount',data=sales_gen)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Amount'>

# %%
sns.countplot(data=df,x='Age Group',hue='Gender')
#from this graph we can see that the age group 26-35 has purchased more.
# Out:
# <AxesSubplot:xlabel='Age Group', ylabel='count'>

# %%
sales_gen=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

# %%
sns.barplot(data=sales_gen,x='State',y='Orders')
# Out:
# <AxesSubplot:xlabel='State', ylabel='Orders'>

# %%
#top 10 most sold products

# %%
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_ID'>

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi_status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28              0
# 1      1000732       Kartik  P00110942      F     26-35   35              1
# 2      1001990        Bindu  P00118542      F     26-35   35              1
# 3      1001425       Sudevi  P00237842      M      0-17   16              0
# 4      1000588         Joni  P00057942      M     26-35   28              1
# ...        ...          ...        ...    ...       ...  ...            ...
# 11246  1000695      Manning  P00296942      M     18-25   19              1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33              0
# 11248  1001209        Oshin  P00201342      F     36-45   40              0
# 11249  1004023       Noonan  P00059442      M     36-45   37              0
# 11250  1002744      Brumley  P00281742      F     18-25   19              0
#
# ...

# %%
df1=df.head(1000)

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
px.bar(df1,x='Age Group',y='Amount')
# Out:
# <div>                            <div id="98973ed8-7850-45ac-99e1-b7bb6fe457d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98973ed8-7850-45ac-99e1-b7bb6fe457d4")) {                    Plotly.newPlot(                        "98973ed8-7850-45ac-99e1-b7bb6fe457d4",                        [{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["26-35","26-35","26-35","0-17","26-35","26-35","18-25","26-35","26-35","26-35","18-25","18-25","26-35","18-25","26-35","51-55","51-55","18-25","46-50","26-35","51-55","55+","26-35","36
# ...

# %%
px.bar(df1,x='Gender',y='Amount')
# Out:
# <div>                            <div id="095be9c3-e85a-40d7-8d49-6308661e1868" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("095be9c3-e85a-40d7-8d49-6308661e1868")) {                    Plotly.newPlot(                        "095be9c3-e85a-40d7-8d49-6308661e1868",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eAmount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["F","F","F","M","M","M","F","M","F","M","F","F","M","F","F","M","M","F","F","F","F","M","F","F","F","M","F","F","F","F","F","F","M","M","F","M","F","M","M","M","F","F","M","F","M","F","F"
# ...

# %%
px.scatter(df1,x='Age',y='Amount',color='Gender',size='Orders')
# Out:
# <div>                            <div id="7cae478d-d04f-474d-997d-9ef189942a47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cae478d-d04f-474d-997d-9ef189942a47")) {                    Plotly.newPlot(                        "7cae478d-d04f-474d-997d-9ef189942a47",                        [{"hovertemplate":"Gender=F\u003cbr\u003eAge=%{x}\u003cbr\u003eAmount=%{y}\u003cbr\u003eOrders=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","size":[1,3,3,4,4,2,2,2,1,4,2,1,2,3,3,4,3,2,3,2,2,4,1,4,2,2,1,4,2,3,1,1,1,3,4,4,4,2,4,1,4,4,2,3,4,4,4,2,1,1,1,4,3,3,4,2,1,2,3,2,1,2,1,2,3,4,2,1,4,1,1,4,2,1,1,3,2,2,3,3,4,4,4,2,2,4,1,3,4,2,2,1,4,1,2,2,2,4,4,3,4,2,2,4,4,1,1,2,2,4,1,1,1,3,1,3,2,1,1,4,3,2,1,1,1,4,4,3,3,4,2,4
# ...

# %%
px.pie(df1,values='Amount',names='Age Group',title='Age wise Amount Spend')
# Out:
# <div>                            <div id="5d80211e-ba7a-49c5-84a3-d954788c7b10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d80211e-ba7a-49c5-84a3-d954788c7b10")) {                    Plotly.newPlot(                        "5d80211e-ba7a-49c5-84a3-d954788c7b10",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Age Group=%{label}\u003cbr\u003eAmount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["26-35","26-35","26-35","0-17","26-35","26-35","18-25","26-35","26-35","26-35","18-25","18-25","26-35","18-25","26-35","51-55","51-55","18-25","46-50","26-35","51-55","55+","26-35","36-45","18-25","51-55","36-45","18-25","26-35","36-45","26-35","51-55","26-35","18-25","26-35","55+","18-25","26-35","26-35","0-1
# ...

# %%
px.box(df1,x='Gender',y='Orders')
# Out:
# <div>                            <div id="cc523be1-bbdd-4735-b45f-cea17f4c3386" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc523be1-bbdd-4735-b45f-cea17f4c3386")) {                    Plotly.newPlot(                        "cc523be1-bbdd-4735-b45f-cea17f4c3386",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eOrders=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["F","F","F","M","M","M","F","M","F","M","F","F","M","F","F","M","M","F","F","F","F","M","F","F","F","M","F","F","F","F","F","F","M","M","F","M","F","M","M","M","F","F","M","F","M","F","F","F","M","F","F","F","M","F",
# ...
